# %%
import pandas as pd
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from tqdm import tqdm
from gensim.models.doc2vec import TaggedDocument
from tqdm import tqdm

# %%
environment = ['환경경영 목표','재생가능한 원자재 및 재활용 또는 포장용 재료','온실가스','에너지','용수 및 폐수','폐기물','오염 물질']

# %%
# data load

bnk = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\BNK금융.xlsx')
kb = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\KB금융.xlsx')
ibk = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\기업은행.xlsx')
shinhan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\신한금융.xlsx')
woori = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\우리금융.xlsx')
hana = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\하나금융.xlsx')

kia = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\자동차\기아자동차.xlsx')
hyundae = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\자동차\현대자동차.xlsx')

lg = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\전자\LG.xlsx')
samsung = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\전자\Samsung.xlsx')

dusan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\두산중공업.xlsx')
samsung_in = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\삼성중공업.xlsx')
hyundae_in = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\현대중공업.xlsx')

daehan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\항공\대한항공_원본.xlsx')
asiana = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\항공\아시아나항공_원본.xlsx')

# %%
# data load
# data load
import pandas as pd

bnk = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\bnk.csv')
kb = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\kb.csv')
ibk = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\ibk.csv')
shinhan = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\shinhan.csv')
woori = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\woori.csv')
hana = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\hana.csv')

kia = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\kia.csv')
hyundae = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\hyundae.csv')

lg = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\lg.csv')
samsung = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\samsung.csv')

dusan = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\dusan.csv')
samsung_in = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\samsung_in.csv')
hyundae_in = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\hyundae_in.csv')

daehan = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\daehan.csv')
asiana = pd.read_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\asiana.csv')

# %%
# 기업 열 추가
bnk['기업'] = 'bnk'
kb['기업'] = 'kb'
ibk['기업'] = 'ibk'
shinhan['기업'] = 'shinhan'
woori['기업'] = 'woori'
hana['기업'] = 'hana'
kia['기업'] = 'kia'
hyundae['기업'] = 'hyundae'
lg['기업'] = 'lg'
samsung['기업'] = 'samsung'
dusan['기업'] = 'dusan'
samsung_in['기업'] = 'samsung_in'
hyundae_in['기업'] = 'hyundae_in'
daehan['기업'] = 'daehan'
asiana['기업'] = 'asiana'

# 파일 병합
full = pd.concat([bnk, kb, ibk, shinhan, woori, hana, kia, hyundae, lg, samsung, dusan, samsung_in, hyundae_in, daehan, asiana])
full.reset_index(drop=True, inplace=True)
full.drop(full.columns[0],axis=1,inplace=True)
full
# Out:
#       발행년도  label                                               text  \
# 0     2019      E  BNK금융그룹은 금융산업의 미래지향적 친환경 경영을 선도하는 환경경영 전략을 추진하...
# 1     2015      E  환경경영 성과 및 지표를 관리하기 위하여 중장기적으로 환경경영시스템을 구축해 나가기...
# 2     2016  N(es)  금융산업의 친환경 경영 선도 부산은행은 환경부 산하 한국환경산업기술원과 연계하여 환...
# 3     2018      O  이해관계자 별 공유 목표 핵심기대 및 요구사항 커뮤니케이션 채널 및 운영 주기는 보...
# 4     2016      O  본부조직은 부서별 특성을 고려한 목표 관리 전략과제를 수립하고 이를 반영한 핵심성과...
# ...    ...    ...                                                ...
# 7479  2012      E  고농도 폐수의 경우 자체 처리 시 오염 부하가 높아지기 때문에 전량 위탁 처리하여 ...
# 7480  2011      E  환경 오염 및 폐기물 감소를 위하여 기내식이 담겨 지는 용품을 합성수지에서 옥수수 ...
# 7481  2012      E  환경 오염 및 폐기물 감소를 위하여 기내식이 담기는 기용품의 LID류를 PET 합성...
# 7482  2011      E  또한 지역 환경 개선에 참여하고 환경친화적 기업 경영과 사전예방적 환경관리에 대한 ...
# 7483  2015      S  특히 항공기 정비 등 작업공정상 사용되는 여러 물질 중 생식독성을 유발할 가능성이 ...
#
#            유사도  keyword      기업
# 0     0.276085  환경경영 목표     bnk
# 1     0.220591  환경경영 목표     bnk
# 2     0.204457  환경경영 목표     bnk
# ...

# %%
dusan.rename(columns={'sentence':'text'},inplace=True)
dusan
# Out:
#       발행년도   label                                               text
# 0     2020       O  대한민국 최초의 근대적 기업인 두산은 -7년의 긴 역사를 거치며 많은 변화를 거듭해...
# 1     2020       O  -7년 배오개현재의 서울 종로 -7가에서 대한민국 최초의 근대적 상점인 박승직 상점...
# 2     2020       O  세계가 인정하는 ISBInfrastructure Support Business의 리...
# 3     2020       O  현재 두산이 보유한 세계일류상품은 총 -7개 품목으로 두산은 세계 최고의 기술을 바...
# 4     2020       O  두산은 유럽 아시아 미주 글로벌 전역에 형성된 네트워크를 중심으로 -7개국에서 활발...
# ...    ...     ...                                                ...
# 5072  2012  N(esg)  두산중공업의 지속가능경영 성과와 앞으로의 계획을 담은 첫번째 보고서를 발간하게 되었...
# 5073  2012       O           앞으로도 두산중공업의 지속가능한 발전을 위해 최선을 다해 노력하겠습니다.
# 5074  2012       O                 본사창원 공장 경상남도 창원시 성산구 두산볼보로 -7 Tel.
# 5075  2012       O             -7 -7 -7 서울 사무소 서울특별시 서초구 강남대로 -7 Tel.
# 5076  2012       E             -7 -7 -7 본 보고서는 친환경 종이에 콩기름으로 인쇄되었습니다.
#
# [5077 rows x 3 columns]

# %%
hyundae.dropna(inplace=True)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 주어진 DataFrame
df = full

# 키워드 리스트
keywords = ['환경경영 목표', '재생가능한 원자재 및 재활용 또는 포장용 재료', '온실가스', '에너지', '용수 및 폐수', '폐기물', '오염 물질']

# TfidfVectorizer를 사용하여 문장 벡터화
vectorizer = TfidfVectorizer()
text_vectors = vectorizer.fit_transform(df['text'])

# 개별 키워드별 DataFrame 생성
keyword_dfs = {}
for i, keyword in enumerate(keywords):
    # 유사도 계산
    keyword_vector = vectorizer.transform([keyword])
    similarity_matrix = cosine_similarity(text_vectors, keyword_vector)
    similarities = similarity_matrix.flatten()

    # DataFrame 생성
    keyword_df = pd.DataFrame({'발행년도': df['발행년도'],
                               'label': df['label'],
                               'text': df['text'],
                               '유사도': similarities})
    keyword_df['keyword'] = keyword

    # 유사도가 큰 순서대로 정렬하여 저장
    keyword_df = keyword_df.sort_values(by='유사도', ascending=False)
    keyword_dfs[f"bnk_{i+1}"] = keyword_df

# 결과 저장
for name, keyword_df in keyword_dfs.items():
    globals()[name] = keyword_df

# %%
combined_df = pd.concat(keyword_dfs.values())
combined_df
# Out:
#       발행년도 label                                               text       유사도  \
# 2151  2010     E                      글로벌 환경경영 체제를 구축하고 환경경영 전략을 수립  0.387315
# 2152  2006     E   -7년 -7월 현대자동차는 글로벌 환경경영 선포식을 통해 환경 경영에 대한 현대자...  0.291276
# 2153  2010     E   이후 환경경영에 대한 현대자동차의 의지와 목표를 담아 환경경영 이념과 글로벌 환경...  0.287606
# 2154  2012     E   현대자동차는 -7년 글로벌 환경경영 선포식을 통해 환경경영 이념과 방침을 대내외에...  0.283299
# 2155  2009     E   기업 경쟁력 제고를 위해 글로벌 환경경영 체제를 구축하고 환경경영 전략을 수립 이...  0.275995
# ...    ...   ...                                                ...       ...
# 2495  2013     O   내부관리의 내재적인 한계에 따른 부정행위 오류 또는 법규 및 규칙의 비준수가 발생...  0.000000
# 2494  2013     E   향후 개발되는 차량들에 이 같은 효율적이고 안전한 재활용 기 술이 적용될 수 있도...  0.000000
# 2493  2010     E   이 출도되는 설계단계에서는 -7년 이후 전 차종에 대 하여 디지털 검증을 실시하여...  0.000000
# 2492  2004     E   특히 엔진오일이나 부동액과 같은 액상재료에 대해 무교환 또는 수명연장기술을 통해 ...  0.000000
# 3742  2017     S   이에 따라 SDGs 선포를 계기로 경영진 및 주요 이해관계자들의 의견을 반영하여 ...  0.000000
#
#       keyword
# 2151  환경경영 목표
# ...

# %%
# 'similarity'가 0인 행 제거
combined_df = combined_df[combined_df['유사도'] != 0]

# 결과 출력
combined_df.reset_index(inplace=True)
combined_df.drop(combined_df.columns[0],axis=1,inplace=True)
combined_df

combined_df.to_csv(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\sent_3\asiana.csv')
# Out:
# c:\Users\user0216\anaconda3\envs\torch\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# 기업 열 추가
bnk['기업'] = 'bnk'
kb['기업'] = 'kb'
ibk['기업'] = 'ibk'
shinhan['기업'] = 'shinhan'
woori['기업'] = 'woori'
hana['기업'] = 'hana'
kia['기업'] = 'kia'
hyundae['기업'] = 'hyundae'
lg['기업'] = 'lg'
samsung['기업'] = 'samsung'
dusan['기업'] = 'dusan'
samsung_in['기업'] = 'samsung_in'
hyundae_in['기업'] = 'hyundae_in'
daehan['기업'] = 'daehan'
asiana['기업'] = 'asiana'

# 파일 병합
full = pd.concat([bnk, kb, ibk, shinhan, woori, hana, kia, hyundae, lg, samsung, dusan, samsung_in, hyundae_in, daehan, asiana])
full.reset_index(drop=True, inplace=True)
full.drop(full.columns[0],axis=1,inplace=True)
full
# Out:
#       발행년도  label                                               text  \
# 0     2019      E  BNK금융그룹은 금융산업의 미래지향적 친환경 경영을 선도하는 환경경영 전략을 추진하...
# 1     2015      E  환경경영 성과 및 지표를 관리하기 위하여 중장기적으로 환경경영시스템을 구축해 나가기...
# 2     2016  N(es)  금융산업의 친환경 경영 선도 부산은행은 환경부 산하 한국환경산업기술원과 연계하여 환...
# 3     2018      O  이해관계자 별 공유 목표 핵심기대 및 요구사항 커뮤니케이션 채널 및 운영 주기는 보...
# 4     2016      O  본부조직은 부서별 특성을 고려한 목표 관리 전략과제를 수립하고 이를 반영한 핵심성과...
# ...    ...    ...                                                ...
# 7479  2012      E  고농도 폐수의 경우 자체 처리 시 오염 부하가 높아지기 때문에 전량 위탁 처리하여 ...
# 7480  2011      E  환경 오염 및 폐기물 감소를 위하여 기내식이 담겨 지는 용품을 합성수지에서 옥수수 ...
# 7481  2012      E  환경 오염 및 폐기물 감소를 위하여 기내식이 담기는 기용품의 LID류를 PET 합성...
# 7482  2011      E  또한 지역 환경 개선에 참여하고 환경친화적 기업 경영과 사전예방적 환경관리에 대한 ...
# 7483  2015      S  특히 항공기 정비 등 작업공정상 사용되는 여러 물질 중 생식독성을 유발할 가능성이 ...
#
#            유사도  keyword      기업
# 0     0.276085  환경경영 목표     bnk
# 1     0.220591  환경경영 목표     bnk
# 2     0.204457  환경경영 목표     bnk
# ...

# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from tqdm import tqdm

# 미리 학습된 BERT 모델과 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=7)

# 입력 문장들과 측면(Aspect) 정의
sentences = full['text']

aspects = ["에너지", "오염물질", "온실가스", "용수","폐기물","환경경영 목표","재생가능한 원자재 및 재활용 또는 포장용 재료"]

# 문장별 측면별 감성 점수 계산
results = []
for i, sentence in tqdm(enumerate(sentences)):
    scores = []
    for aspect in (aspects):
        input_text = f"[CLS] {aspect}: {sentence} [SEP]"
        inputs = tokenizer(input_text, truncation=True, padding=True, return_tensors="pt")
        outputs = model(**inputs)
        logits = outputs.logits
        score = torch.softmax(logits, dim=1).tolist()[0][1]
        scores.append(score)
    results.append(scores)

# 결과를 데이터프레임 형태로 출력
df = pd.DataFrame(results, columns=aspects)
df['기업'] = full['기업']
df = df[['기업'] + aspects]  # '기업' 열을 첫 번째 열로 위치 조정

# 결과 출력
df
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
df_mean = df.groupby('기업')[aspects].mean()
df_mean
# Out:
#           에너지      오염물질      온실가스        용수       폐기물   환경경영 목표  \
# 기업
# bnk  0.139081  0.139786  0.138183  0.139088  0.139868  0.140183
#
#      재생가능한 원자재 및 재활용 또는 포장용 재료
# 기업
# bnk                   0.138658

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 주어진 DataFrame
df = bnk

# 발행년도 별 label 개수 계산
label_counts = df.groupby('발행년도')['label'].value_counts().unstack(fill_value=0)

# 히스토그램 생성
label_counts.plot(kind='bar', stacked=True)

# 그래프 설정
plt.xlabel('발행년도')
plt.ylabel('개수')
plt.title('발행년도 별 label 개수')
plt.legend(title='Label')
plt.xticks(rotation=0)

# 그래프 출력
plt.show()

# %%
bnk_2018 = bnk[bnk['발행년도']==2018]
bnk_2018
#len(bnk_2018[bnk_2018['label']=='E'])
# Out:
#       발행년도 label                                               text
# 649   2018     O  공동으로 개발한 DJSI 아시아퍼시픽지수Dow Jones Sustainability...
# 650   2018     O  DJSI는 전 세계 시가총액 상위 -7여 개의 BNK금융그룹은 양호한 경영성과 사회...
# 651   2018     O  앞으로도 지 역금융그룹으로서 책임을 다하고 -7년 기업으로 지 BNK금융그룹은 지속...
# 652   2018     O  본 보고서는 BNK금융그룹이 발간하는 여섯 번째 지속가능경영보고서로 GRIGloba...
# 653   2018     O  또한 중대성 평가를 통해 도출된 핵심 이슈는 그룹의 -7대 경영원칙인 고객감동 경영...
# ...    ...   ...                                                ...
# 1513  2018     O  일G반R표준I 공대개조Univ표ersal Standards Disclosures -...
# 1514  2018     O                              행-7과 지역 금융 -7주-7B-7S.
# 1515  2018     O                                            -7금-7융.
# 1516  2018     O  -7지-7주 b부il문ity신In규de편x입AsiaPacific BNK금융그룹의 지...
# 1517  2018     E  본 보고서는 책임있는 산림에서 개발 관리된 생산 목재를 사용한 제품에만 부착되는 F...
#
# [869 rows x 3 columns]

# %%
len(bnk_2015[bnk_2015['label']=='E'])
# Out:
# 44

# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# 미리 학습된 BERT 모델과 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=7)

# 입력 문장들과 측면(Aspect) 정의
sentences = bnk_2018['text']

aspects = ["에너지", "오염물질", "온실가스", "용수","폐기물","환경경영 목표","재생가능한 원자재 및 재활용 또는 포장용 재료"]

# 문장별 측면별 감성 점수 계산
results = []
for i, sentence in tqdm(enumerate(sentences)):
    scores = []
    for aspect in (aspects):
        input_text = f"[CLS] {aspect}: {sentence} [SEP]"
        inputs = tokenizer(input_text, truncation=True, padding=True, return_tensors="pt")
        outputs = model(**inputs)
        logits = outputs.logits
        score = torch.softmax(logits, dim=1).tolist()[0][1]
        scores.append(score)
    results.append(scores)

# 결과를 데이터프레임 형태로 출력
df = pd.DataFrame(results, columns=aspects)
df['기업'] = 'bnk'
df = df[['기업'] + aspects]  # '기업' 열을 첫 번째 열로 위치 조정

# 결과 출력
df
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
df_mean = df.groupby('기업')[aspects].mean()
df_mean
# Out:
#          에너지      오염물질      온실가스        용수       폐기물   환경경영 목표  \
# 기업
# bnk  0.17008  0.170039  0.171855  0.173922  0.168877  0.175652
#
#      재생가능한 원자재 및 재활용 또는 포장용 재료
# 기업
# bnk                   0.176279

# %%
df_mean.values.mean()
# Out:
# 0.17238620480394823

# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# 미리 학습된 BERT 모델과 토크나이저 로드
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=7)

# 입력 문장들과 측면(Aspect) 정의
sentences = bnk_2015['text']

aspects = ["에너지", "오염물질", "온실가스", "용수","폐기물","환경경영 목표","재생가능한 원자재 및 재활용 또는 포장용 재료"]

# 문장별 측면별 감성 점수 계산
results = []
for i, sentence in tqdm(enumerate(sentences)):
    scores = []
    for aspect in (aspects):
        input_text = f"[CLS] {aspect}: {sentence} [SEP]"
        inputs = tokenizer(input_text, truncation=True, padding=True, return_tensors="pt")
        outputs = model(**inputs)
        logits = outputs.logits
        score = torch.softmax(logits, dim=1).tolist()[0][1]
        scores.append(score)
    results.append(scores)

# 결과를 데이터프레임 형태로 출력
df = pd.DataFrame(results, columns=aspects)
df['기업'] = 'bnk'
df = df[['기업'] + aspects]  # '기업' 열을 첫 번째 열로 위치 조정

# 결과 출력
df
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
df_mean = df.groupby('기업')[aspects].mean()
df_mean
# Out:
#           에너지      오염물질      온실가스        용수       폐기물   환경경영 목표  \
# 기업
# bnk  0.128247  0.124442  0.125309  0.125412  0.125664  0.129151
#
#      재생가능한 원자재 및 재활용 또는 포장용 재료
# 기업
# bnk                   0.124807

# %%
sum([0.128247,0.124442,0.125309,0.125412,0.125664,0.129151,0.124807])/7
# Out:
# 0.12614742857142858
