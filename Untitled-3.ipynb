# %%
# data load

import pandas as pd
bnk = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\BNK금융.xlsx')
kb = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\KB금융.xlsx')
ibk = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\기업은행.xlsx')
shinhan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\신한금융.xlsx')
woori = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\우리금융.xlsx')
hana = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\금융\하나금융.xlsx')


kia = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\자동차\기아자동차.xlsx')
hyundae = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\자동차\현대자동차.xlsx')

lg = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\전자\LG.xlsx')
samsung = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\전자\Samsung.xlsx')

dusan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\두산중공업.xlsx')
samsung_in = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\삼성중공업.xlsx')
hyundae_in = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\중공업\현대중공업.xlsx')

daehan = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\항공\대한항공_원본.xlsx')
asiana = pd.read_excel(r'C:\Users\user0216\OneDrive - Sejong University\바탕 화면\ESG_classificaion_KG\개인\new\data\항공\아시아나항공_원본.xlsx')

finance = bnk.append([kb,ibk,shinhan,woori,hana, kia,hyundae, lg,samsung, dusan,samsung_in, hyundae_in,daehan,asiana])

data_e = finance.loc[finance['label'] == 'E']
data_s = finance.loc[finance['label'] == 'S']
data_g = finance.loc[finance['label'] == 'G']
data_o = finance.loc[finance['label'] == 'O']
data_n = finance[finance['label'].str.contains('N',na=True)]
data_n['label'] = 'N'
data = data_e.append([data_s,data_g, data_o,data_n], sort=False)
# Out:
# c:\Users\user0216\anaconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
data = data.drop(['발행년도','sentence'],axis=1)
data.dropna(inplace=True)
data = data.reset_index()
data = data.drop([data.columns[0]], axis=1)
data
'''

# %%
data_e = data_e.drop(['발행년도','sentence'],axis=1)
data_e.dropna(inplace=True)
data_e = data_e.reset_index()
data_e = data_e.drop([data_e.columns[0]], axis=1)
data_e
# Out:
#       label                                               text
# 0         E  한편 장기적으로 국제 사회에 큰 위협이 될 것으로 예상되는 기후변화에 대한 대응체계...
# 1         E  기후변화의 규제 강화에 따라 투자사업들에 대한 리스크 익스포저의 변화 투자 수익률의...
# 2         E  그리고 이 를 통해 금융을 통한 환경보호 및 기후변화 대응을 실현하기 위한 토대를 ...
# 3         E  BNK금융그룹은 금융산업의 미래지향적 친환경 경영을 선도하는 환경경영 전략을 추진하...
# 4         E            너지 절감 활동을 추진함으로써 효율적으로 환경경영을 실천하고 있습니다.
# ...     ...                                                ...
# 15339     E  -7년 -7월부터 국내 항공사 중 최초로 세계적인 친환경 비정부 기구인 RARain...
# 15340     E  RA 인증 커피는 세계적인 친환경 NGO인 열대우림동맹RA Rainforest Al...
# 15341     E    매 분기별 전사적으로 환경 행사를 시행하여 전 임직원의 환경의식을 함양하고 있습니다.
# 15342     E  ANA와의 공동 사회공헌 함께 가꾸는 환경 아시아나항공은 일본 ANA항공과 함께 공...
# 15343     E  -7년 하반기 일본 요나고 공항 인근에서 양사가 함께하는 첫 번째 식목 행사로 소나...
#
# [15344 rows x 2 columns]

# %%
data_s = data_s.drop(['발행년도','sentence'],axis=1)
data_s.dropna(inplace=True)
data_s = data_s.reset_index()
data_s = data_s.drop([data_s.columns[0]], axis=1)
data_s
# Out:
#       label                                               text
# 0         S  BNK금융그룹은 고객의 성공과 경제적 행복 실현을 위한 차별화된 고객 서비스CS를 ...
# 1         S  또한 각종 금융 범죄로부터 금융소비자를 보호하며 금융소비자의 금융 접근 편의를 위한...
# 2         S                      셋째금융의 사회적 가치 창출을 위해 앞장 서겠습니다.
# 3         S  그룹 경영이념을 바탕으로 인권 노동 환경 반부패 등에 적극적인 관심을 가지며 전 계...
# 4         S  또한 금융소외 계층을 위한 공익상품 개발과 중소벤처기업에 대한 대출 및 투자지원에도...
# ...     ...                                                ...
# 37975     S  -7년 상반기에는 사랑의 집 -7호를 오픈하는 성과를 올렸으며 앞으로도 베트남 사랑...
# 37976     S  중국 지역 사랑의 물 나누기 운동 -7년 -7월부터 중국부녀발전기금회 주관의 전 국...
# 37977     S  아시아나항공의 중국 전 지점 카운터 및 공항 지역에 사랑의 물 나누기 모금함과 홍보...
# 37978     S                 또한 연말연시 사랑의 점퍼 나누 기 행사도 후원하고 있습니다.
# 37979     S  중앙아시아 사할린 지점 사할린 지점에서는 한인 -7세 노인들이 외롭게 살고 있는 브...
#
# [37980 rows x 2 columns]

# %%
data_g = data_g.drop(['발행년도','sentence'],axis=1)
data_g.dropna(inplace=True)
data_g = data_g.reset_index()
data_g = data_g.drop([data_g.columns[0]], axis=1)
data_g
# Out:
#      label                                               text
# 0        G  또한 BNK금융그룹은 희망을 주는 행복한 금융 이라는 사회적 책임 목표 아래 투명한...
# 1        G                        둘째경영과 지배구조의 투명성을 더욱 높이겠습니다.
# 2        G  BNK금융그룹은 우리 사회가 요구하는 투명한 경영시스템과 선진화된 지배구조를 위한 ...
# 3        G  이사회 독립성을 최대한 보장하고 다양한 경험과 전문성을 가진 이사를 선임하는 등 경...
# 4        G  BNK금융그룹은 당사 경영활동에 영향을 미치는 이해관계자들의 니즈를 보다 효율적으로...
# ...    ...                                                ...
# 7068     G  또한 효과적인 내부 통제 운영을 위하여 내부 통제 세부 운영지침을 제정하고 이를 바...
# 7069     G  -7년 상반기 -7건 하반기 -7건의 핵심 통제에 대한 내부 회계관리 제도 운영실태...
# 7070     G  재무 내부 감사 아시아나항공은 지점 업무 수행 중 발생하는 다양한 리스크 관리를 통...
# 7071     G  그룹 윤리강령 실천 가능한 부분부터 성실히 실천하자라는 마음가짐으로 임직원의 행동과...
# 7072     G  임직원의 도덕적 윤리의식 함양과 이에 따른 투명경영실천을 목표로 윤리감사팀을 중심으...
#
# [7073 rows x 2 columns]

# %%
# Select sentences that include particular words
words_to_match = '환경'

output = []
for sentence in data_c:
    for word in words_to_match:
        if word in sentence:
            output.append(sentence)
            break
output

# %%
topics
# Out:
# defaultdict(list,
#             {0: ['사업', '태양광', '재생', '7월', '수상'],
#              1: ['공신력', '실험실', '고안', '과다', 'utility'],
#              2: ['경영', '환경', '녹색', '기업', '금융'],
#              3: ['보호', '생태계', '우리', '다양성', '생물'],
#              4: ['가스', '온실', '7년', '배출량', '배출'],
#              5: ['물질', '관리', '화학', '유해', '대하'],
#              6: ['연비', '엔진', '하이브리드', '연료', '자동차'],
#              7: ['제품', '에너지', '효율', '사용', '절감'],
#              8: ['발생', '폐기물', '재활용', '처리', '공정']})

# %%
'''
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sentences = data_e['text']
word = '효율'

# TfidfVectorizer 객체를 생성하여 문장들과 단어들을 벡터화한다.
vectorizer = TfidfVectorizer(use_idf=True, norm='l2')
corpus = sentences + [word]
X = vectorizer.fit_transform(corpus)

# 벡터화된 문장들과 단어의 코사인 유사도를 계산한다.
similarity_matrix = cosine_similarity(X)

# 유사도 출력
print(similarity_matrix[:len(sentences), len(sentences)])
'''
# Out:
# array([[1.        , 0.06957119, 0.08898174, ..., 0.02205923, 0.01223645,
#         0.00342066],
#        [0.06957119, 1.        , 0.00370017, ..., 0.00355284, 0.00197079,
#         0.00172656],
#        [0.08898174, 0.00370017, 1.        , ..., 0.02507769, 0.01391082,
#         0.00388872],
#        ...,
#        [0.02205923, 0.00355284, 0.02507769, ..., 1.        , 0.08676879,
#         0.10420801],
#        [0.01223645, 0.00197079, 0.01391082, ..., 0.08676879, 1.        ,
#         0.18217205],
#        [0.00342066, 0.00172656, 0.00388872, ..., 0.10420801, 0.18217205,
#         1.        ]])

# %%
sentences = data_e['text']
word_list = topics[3]

# 각 단어의 빈도수를 저장할 딕셔너리를 생성한다.
word_count = {word: 0 for word in word_list}

# 문장들에서 각 단어가 등장한 횟수를 센다.
for sentence in sentences:
    for word in word_list:
        count = sentence.lower().count(word)
        word_count[word] += count

# 가장 높은 빈도수를 갖는 단어를 찾는다.
max_count = max(word_count.values())
most_frequent_words = [word for word, count in word_count.items() if count == max_count]

# 결과 출력
print("The most frequent word(s) is: {}".format(', '.join(most_frequent_words)))
# Out:
# The most frequent word(s) is: 보호

# %%
most_frequent_words = ''.join(most_frequent_words)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# 예시 문장 데이터
sentences = data_e['text']

# 예시 단어 데이터
keyword = most_frequent_words

# TfidfVectorizer로 문장과 단어 벡터화
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
sentences_vectors = tfidf_vectorizer.fit_transform(sentences)
keyword_vector = tfidf_vectorizer.transform([keyword])

# 문장과 단어 벡터간 코사인 유사도 계산
cosine_similarities = cosine_similarity(sentences_vectors, keyword_vector)

# 결과를 DataFrame으로 출력
df = pd.DataFrame(cosine_similarities, columns=['similarity'])
df['text'] = ''
df['text'] = sentences
df
# Out:
#        similarity                                               text
# 0             0.0  한편 장기적으로 국제 사회에 큰 위협이 될 것으로 예상되는 기후변화에 대한 대응체계...
# 1             0.0  기후변화의 규제 강화에 따라 투자사업들에 대한 리스크 익스포저의 변화 투자 수익률의...
# 2             0.0  그리고 이 를 통해 금융을 통한 환경보호 및 기후변화 대응을 실현하기 위한 토대를 ...
# 3             0.0  BNK금융그룹은 금융산업의 미래지향적 친환경 경영을 선도하는 환경경영 전략을 추진하...
# 4             0.0            너지 절감 활동을 추진함으로써 효율적으로 환경경영을 실천하고 있습니다.
# ...           ...                                                ...
# 15339         0.0  -7년 -7월부터 국내 항공사 중 최초로 세계적인 친환경 비정부 기구인 RARain...
# 15340         0.0  RA 인증 커피는 세계적인 친환경 NGO인 열대우림동맹RA Rainforest Al...
# 15341         0.0    매 분기별 전사적으로 환경 행사를 시행하여 전 임직원의 환경의식을 함양하고 있습니다.
# 15342         0.0  ANA와의 공동 사회공헌 함께 가꾸는 환경 아시아나항공은 일본 ANA항공과 함께 공...
# 15343         0.0  -7년 하반기 일본 요나고 공항 인근에서 양사가 함께하는 첫 번째 식목 행사로 소나...
#
# [15344 rows x 2 columns]

# %%
df.sort_values(by='similarity',ascending=False,inplace=True)
df.reset_index(inplace=True)
df.drop(df.columns[0],axis=1,inplace=True)
df
# Out:
#        similarity                                               text
# 0        0.420439                  현대자동차는 생태계 보호 및 복원 사업을 추진하고 있습니 다
# 1        0.414116   생물다양성 보호 대한항공은 생물다양성 보호를 위한 항공운송업체 의 역할을 인지하고...
# 2        0.379967                    구미사업장은 야생동물 보호 활동에 적극 앞장서고 있습니다
# 3        0.338649   장기적 관점에서 그린존 프로젝트 숲보호 활동 및 멸종위 기 보호 사업과 더불어 가...
# 4        0.318424          아울러 인근 멸종 위기종을 파악하여 서식 지 보호 활동을 추진하고 있습니다
# ...           ...                                                ...
# 15339    0.000000   -7년의 경우 공장에 공급되는 압축공기 설비에 -7억 원을 투자하여 고효율 장 비...
# 15340    0.000000   lnG 소 모가 많은 소재공장에는 열손실을 방지하기 위해 가열설비 를 교체 개선하...
# 15341    0.000000   또 한 친환경 정부정책에 동참하기 위해 다양한 신재생에너 지 및 신사업을 검토하여...
# 15342    0.000000   이러 한 노력의 결과 울산사업장의 자동차 생산량은 전년 대비 -7 증가하였으나 자...
# 15343    0.000000  -7년 하반기 일본 요나고 공항 인근에서 양사가 함께하는 첫 번째 식목 행사로 소나...
#
# [15344 rows x 2 columns]

# %%
cnt = 0

for i in range(len(df)):
    if df['similarity'][i] == 0:
        cnt += 1
cnt
# Out:
# 15180

# %%
15344-13985
# Out:
# 1359

# %%
e3 = []
for i in range(len(df)):
    if df['similarity'][i] >=0.2:
        e3.append(df.loc[i])
e3 = pd.DataFrame(e3)

# %%
e3 = []
for i in range(len(df)):
    if df['similarity'][i] >=0.2:
        e3.append(df.loc[i])
e3 = pd.DataFrame(e3)
# Out:
#     similarity                                               text
# 0     0.381238   이 사업 은 가전제품 생산 및 판매를 통한 CDM 사업 중에서 는 세계 최초의 사...
# 1     0.332891     현대자동차는 모든 사업 활동에서 환경에 미치는 영향을 줄이기 위해 노력하고 있습니다
# 2     0.332331      삼성전자는 모든 사업 활동에서 환경에 미치는 영향을 줄이기 위해 노력하고 있습니다
# 3     0.312598  또한 EV를 활용한 친환경 모빌리티 사업 전개와 목적 기반 모빌리티인 PBV 사업 ...
# 4     0.301678  사업 운영이 환경에 미치는 영향을 최소화하기 위해 지속적인 환경 투자를 시행하고 있...
# 5     0.279580    물 사용량은 태양전지 등 신규 사업 추진과 함께 지속적으로 늘어날 것 으로 예상됩니다
# 6     0.273971       -7년에는 전세계 사업 장이 글로벌 환경경영 시스템 관리 체계를 갖출 예정입니다
# 7     0.272678  두 사업 모두 기후변화에 관한 UN기본협약UNFCCC에 등록 되었으며 특히 수도권매...
# 8     0.270995    기업의 사업 영역과 활동 지역 등을 고려한 녹색금융상품을 개발하여 운영하고 있습니다.
# 9     0.264178   또한 글로벌 사업 확대에 따라 해 외사업장을 대상으로 환경경영 시행을 위한 관리를...
# 10    0.260635   운영조직LG전자는 생산 단계 및 제품 사용 단계의 온실가스 저감을 주요 사업 목표...
# 11    0.257320              이는 가전 제품 부문의 청정개발체제 사업 중 세계 최대 규모입 니다
# 12    0.251652  KB국민은행은 -7년 -7월 친환경친사회적인 사업 지원을 확대하기 위해 지속가능금융...
# ...

# %%
df['similarity'][190]
# Out:
# 0.09687231948391119

# %%
a = sum(df['similarity'])/(len(df)-cnt)
a

# %%
num = 0

for i in range(len(df)):
    if df['similarity'][i] > a :
        num += 1
num

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# nltk 패키지에서 VADER 감성분석기를 불러옵니다.
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

senetences = df['text']

# VADER 감성분석기를 이용해 문장의 감정 점수를 계산합니다.
for sentence in sentences:
    scores = sid.polarity_scores(sentence)
    compound_score = scores['compound']
    #print("{:.3f}".format(compound_score))
print(compound_score)

# %% [markdown]
# topic modeling

# %%
""" 키워드 추출 from title """
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from tqdm import tqdm

kkma = Kkma()
komoran = Komoran()

#텍스트 데이터를 리스트로 변환
Data_list=data_e['text']

#리스트를 요소별로(트윗 하나) 가져와서 명사만 추출한 후 리스트로 저장
data_word=[]
for i in tqdm(range(len(Data_list))):
    try:
        data_word.append(komoran.nouns(Data_list[i]))
    except Exception as e:
        continue

#트윗에서 명사만 추출해서 만든 리스트
data_word
# Out:
# 100%|██████████| 15344/15344 [00:30<00:00, 505.20it/s]
# [['한편', '장기', '국제', '사회', '위협', '것', '예상', '기후', '변화', '대응', '체계', '강화'],
#  ['기후',
#   '변화',
#   '규제',
#   '강화',
#   '투자',
#   '사업',
#   '리스크',
#   '익스',
#   '포',
#   '변화',
#   '투자',
#   '수익률',
#   '감소',
#   '등',
#   '예상',
#   '가운데',
#   'BNK금융그룹',
#   '탄소',
#   '경제',
#   '이행',
#   '녹색',
#   '금융 서비스',
#   '소비자',
#   '수요',
#   '증가',
#   '대비',
#   '환경',
#   '경영',
#   '강화',
#   '친환경',
#   '금융',
#   '확대',
#   '실행',
#   '시',
#   '환경영향평가',
#   '시행',
#   '등',
#   '환경',
#   '분야',
#   '리스크',
#   '관리',
#   '기법',
#   '적용',
#   '중'],
#  ['금융', '환경', '보호', '기후', '변화', '대응', '실현', '토대', '구축'],
#  ['BNK금융그룹',
#   '금융',
#   '산업',
#   '미래',
#   '지향',
#   '친환경',
#   '경영',
#   '선도',
#   '환경',
#   '경영',
#   '전략',
#   '추진',
#   '니다'],
#  ['지', '절감', '활동', '추진', '효율', '환경', '경영', '실천'],
#  ['BNK금융그룹',
#   '에너지 절약',
#   '친환경',
#   '관련',
#   '사적',
#   '캠페인',
#   '실시',
#   '임직원',
#   '자발',
#   '적',
#   '에너지 절약',
#   '친환경',
#   '문화',
#   '확산',
# ...

# %%
s = sum(data_word,[])
s

# %%
from collections import Counter

counter = Counter(s)
counter.most_common(10)

# %%
available_counter = Counter({x: counter[x] for x in counter if len(x) > 1})
available_counter.most_common(10)

# %%
# %pip install contextualized-topic-models==2.2.0

# %%
# %pip install pyldavis

# %%
documents = data_e['text'].tolist()

# %%
preprocessed_documents = []

for line in tqdm(documents):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 15344/15344 [00:00<00:00, 300856.42it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Komoran())

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation, bert_embeddings_from_list
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
train_bow_embeddings = vectorizer.fit_transform(preprocessed_documents)

# %%
print(train_bow_embeddings.shape)
# Out:
# (15344, 3000)

# %%
vocab = vectorizer.get_feature_names()
id2token = {k: v for k, v in zip(range(0, len(vocab)), vocab)}
# Out:
# c:\Users\user0216\anaconda3\envs\torch\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
len(vocab)
# Out:
# 3000

# %%
train_contextualized_embeddings = bert_embeddings_from_list(preprocessed_documents, \
                                                            "sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens")
# Out:
# Batches:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
qt = TopicModelDataPreparation()

training_dataset = qt.load(train_contextualized_embeddings, train_bow_embeddings, id2token)

# %%
# combined TM 학습하기
# topic model 학습
# n_components로 토픽 개수 조정 가능

ctm = CombinedTM(bow_size=len(vocab), contextual_size=768, n_components=9, num_epochs=20)
ctm.fit(training_dataset)
# Out:
# Epoch: [20/20]	 Seen Samples: [306880/306880]	Train Loss: 160.30825732472792	Time: 0:00:36.396000: : 20it [12:18, 36.91s/it]

# %%
topics = ctm.get_topics(5)

# %%
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(vocab, training_dataset, n_samples=10)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# Sampling: [10/10]: : 10it [05:54, 35.40s/it]
# c:\Users\user0216\anaconda3\envs\torch\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2286023063658658004896065677"></div>
# <script type="text/javascript">
#
# ...

# %%
topics
# Out:
# defaultdict(list,
#             {0: ['물질', '환경', '제품', '유해', '관리'],
#              1: ['지역', '생물', '보존', '보호', '다양성'],
#              2: ['발생', '폐기물', '처리', '오염', '물질'],
#              3: ['자동차', '현대자동차', '하이브리드', '수소', '차량'],
#              4: ['전자', '에너지', 'lg', '재생', '확대'],
#              5: ['가스', '온실', '7년', '배출량', '감축'],
#              6: ['연료', '효율', '항공기', '시키', '절감'],
#              7: ['premium', '실험실', '입력', '공신력', 'scep'],
#              8: ['변화', '기후', '경영', '녹색', '금융']})
